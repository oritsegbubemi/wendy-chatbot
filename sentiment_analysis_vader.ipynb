# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import string

print(os.listdir("./dataset/"))
# Out:
# ['clean_test.csv', 'clean_train.csv', 'survey_questions.csv', 'test.csv', 'train.csv']

# %%
import warnings
warnings.filterwarnings('ignore')

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize, WhitespaceTokenizer
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.probability import FreqDist
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import RegexpTokenizer
from nltk import pos_tag

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, cross_val_score
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, roc_auc_score, accuracy_score

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from wordcloud import WordCloud

# add sentiment anaylsis columns
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# create doc2vec vector columns
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
df_train = pd.read_csv('./dataset/clean_train.csv')
df_test = pd.read_csv('./dataset/clean_test.csv')

# %%
drop_col = ['job_title', 'score_1', 'score_2', 'score_3', 'score_4', 'score_5', 'score_6']
df_train.drop(columns=drop_col, inplace=True)
df_test.drop(columns=drop_col, inplace=True)

# %%
df_train.head(3)
# Out:
#        Place             status  \
# 0  startup_1  Current Employee
# 1  startup_1   Former Employee
# 2  startup_1  Current Employee
#
#                                              summary  \
# 0                           Best Company to work for
# 1  Moving at the speed of light, burn out is inev...
# 2  Great balance between big-company security and...
#
#                                            positives  \
# 0                      People are smart and friendly
# 1  1) Food, food, food. 15+ cafes on main campus ...
# 2  * If you're a software engineer, you're among ...
#
#                                            negatives  \
# 0                 Bureaucracy is slowing things down
# 1  1) Work/life balance. What balance? All those ...
# 2  * It *is* becoming larger, and with it comes g...
#
#                                       advice_to_mgmt  overall  len_pos  \
# 0                                                NaN        5       29
# 1  1) Don't dismiss emotional intelligence and ad...        5     1048
# 2  Keep the focus on the user. Everything else wi...        5     3634
#
#    len_neg  num_words_pos  num_words_neg  \
# 0       34              5              5
# 1     2403            155            398
# 2     1064            629            176
#
#                                      clean_positives  \
# 0                              people smart friendly
# 1  food food food cafe main campus mtv alone mini...
# 2  software engineer among king hill google engin...
#
#                                      clean_negatives  \
# 0                             bureaucracy slow thing
# 1  work/life balance balance perk benefit illusio...
# 2  become large come grow pain bureaucracy slow r...
#
#                                        clean_reviews
# 0       people smart friendly bureaucracy slow thing
# 1  food food food cafe main campus mtv alone mini...
# 2  software engineer among king hill google engin...

# %%
def SIAscores(df):
    SIA = SentimentIntensityAnalyzer()
    df["pos_sentiments"] = df["clean_positives"].apply(lambda x: SIA.polarity_scores(str(x)))
    df["neg_sentiments"] = df["clean_negatives"].apply(lambda x: SIA.polarity_scores(str(x)))
    df["review_sentiments"] = df["clean_reviews"].apply(lambda x: SIA.polarity_scores(str(x)))
    df["review_negative"] = [d.get('neg') for d in df["review_sentiments"]]
    df["review_neutral"] = [d.get('neu') for d in df["review_sentiments"]]
    df["review_positive"] = [d.get('pos') for d in df["review_sentiments"]]
    df["review_compound"] = [d.get('compound') for d in df["review_sentiments"]]

# %%
SIAscores(df_train)
SIAscores(df_test)

# %%
df_train.sample(5)
# Out:
#            Place             status                                   summary  \
# 6187   startup_4  Current Employee   Great Place, Great People, Great Culture
# 22917  startup_6  Current Employee                        Solid place to work
# 24088  startup_6   Former Employee                              Great Company
# 22501  startup_6  Current Employee                       Decent Place to Work
# 24401  startup_6   Former Employee                           research program
#
#                                                positives  \
# 6187   - fast moving, if you are excited about techno...
# 22917  - Benefits!! - Good work/life balance - Intere...
# 24088  Great Company fun place to work, managers coul...
# 22501  Little/no stress, work/life balance, decent pa...
# 24401  great program. You will learn a lot. Fun envir...
#
#                                                negatives  \
# 6187   - frugal, if you like sprawling offsite campus...
# 22917  - Bureaucratic - Development processes can be ...
# 24088    If you get a bad manager, you have on recourse.
# 22501  Sometimes politics gets in the way, promotion ...
# 24401              didn't find many cons at this program
#
#                          advice_to_mgmt  overall  len_pos  len_neg  \
# 6187   keep up the startup type culture        5      629      427
# 22917                               NaN        4       65       93
# 24088                               NaN        5       57       47
# 22501                               NaN        5       83       87
# 24401                               NaN        5       62       37
#
#        num_words_pos  ...                                    clean_positives  \
# 6187             112  ...  fast move excited technology right place flat ...
# 22917             10  ...  benefit good work/life balance interesting pro...
# 24088             10  ...  great company fun place work manager could better
# 22501              9  ...  little/no stress work/life balance decent pay ...
# 24401             12  ...            great program learn lot fun environment
#
#                                          clean_negatives  \
# 6187   frugal like sprawl offsite campus lush green g...
# 22917  bureaucratic development process slow internal...
# 24088                           get bad manager recourse
# 22501  sometimes politics get way promotion mostly ba...
# 24401                              find many con program
#
#                                            clean_reviews  \
# 6187   fast move excited technology right place flat ...
# 22917  benefit good work/life balance interesting pro...
# 24088  great company fun place work manager could bet...
# 22501  little/no stress work/life balance decent pay ...
# 24401  great program learn lot fun environment find m...
#
#                                           pos_sentiments  \
# 6187   {'neg': 0.089, 'neu': 0.605, 'pos': 0.306, 'co...
# 22917  {'neg': 0.0, 'neu': 0.317, 'pos': 0.683, 'comp...
# 24088  {'neg': 0.0, 'neu': 0.327, 'pos': 0.673, 'comp...
# 22501  {'neg': 0.323, 'neu': 0.462, 'pos': 0.215, 'co...
# 24401  {'neg': 0.0, 'neu': 0.351, 'pos': 0.649, 'comp...
#
#                                           neg_sentiments  \
# 6187   {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'comp...
# 22917  {'neg': 0.307, 'neu': 0.693, 'pos': 0.0, 'comp...
# 24088  {'neg': 0.538, 'neu': 0.462, 'pos': 0.0, 'comp...
# 22501  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 24401  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
#                                        review_sentiments review_negative  \
# 6187   {'neg': 0.056, 'neu': 0.664, 'pos': 0.28, 'com...           0.056
# 22917  {'neg': 0.137, 'neu': 0.485, 'pos': 0.379, 'co...           0.137
# 24088  {'neg': 0.161, 'neu': 0.367, 'pos': 0.472, 'co...           0.161
# 22501  {'neg': 0.183, 'neu': 0.696, 'pos': 0.122, 'co...           0.183
# 24401  {'neg': 0.0, 'neu': 0.519, 'pos': 0.481, 'comp...           0.000
#
#        review_neutral  review_positive  review_compound
# 6187            0.664            0.280           0.9823
# 22917           0.485            0.379           0.6705
# 24088           0.367            0.472           0.7783
# 22501           0.696            0.122          -0.1027
# 24401           0.519            0.481           0.8126
#
# [5 rows x 21 columns]

# %% [markdown]
# # Testing

# %%
analyser = SentimentIntensityAnalyzer()

def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    print("{} {}".format(sentence, str(score)))
    if (score['compound'] >= 0.67):
        print("Very Happy")
    elif (score['compound'] >= 0.33 and score['compound'] < 0.67):
        print("Happy")
    elif (score['compound'] >= -0.33 and score['compound'] < 0.33):
        print("Neutral")
    elif (score['compound'] >= -0.67 and score['compound'] < -0.33):
        print("Quite Unhappy")
    else:
        print("Unhappy")

# %%
sentiment_analyzer_scores("I am very HAPPY!!")
# Out:
# I am very HAPPY!! {'neg': 0.0, 'neu': 0.274, 'pos': 0.726, 'compound': 0.7438}
# Very Happy
